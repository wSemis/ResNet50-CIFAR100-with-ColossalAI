# %%
# !colossalai check -i
# Out:
# #### Installation Report ####
#
# ------------ Environment ------------
# Colossal-AI version: 0.3.6
# PyTorch version: 2.0.1
# System CUDA version: 11.7
# CUDA version required by PyTorch: 11.7
#
# Note:
# 1. The table above checks the versions of the libraries/tools in the current environment
# 2. If the System CUDA version is N/A, you can set the CUDA_HOME environment variable to locate it
# 3. If the CUDA version required by PyTorch is N/A, you probably did not install a CUDA-compatible PyTorch. This value is give by torch.version.cuda and you can go to https://pytorch.org/get-started/locally/ to download the correct version.
#
# ------------ CUDA Extensions AOT Compilation ------------
# Found AOT CUDA Extension: ✓
# PyTorch version used for AOT compilation: N/A
# CUDA version used for AOT compilation: N/A
#
# Note:
# 1. AOT (ahead-of-time) compilation of the CUDA kernels occurs during installation when the environment variable BUILD_EXT=1 is set
# ...

# %%
# !colossalai run --nproc_per_node 4 train.py -c ./ckpt-fp16 -p torch_ddp_fp16 > run.log
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# /home/wdebang/hdd/miniconda3/envs/py10/lib/python3.10/site-packages/colossalai/shardformer/layer/normalization.py:45: UserWarning: Please install apex from source (https://github.com/NVIDIA/apex) to use the fused layernorm kernel
#   warnings.warn("Please install apex from source (https://github.com/NVIDIA/apex) to use the fused layernorm kernel")
# /home/wdebang/hdd/miniconda3/envs/py10/lib/python3.10/site-packages/colossalai/shardformer/layer/normalization.py:45: UserWarning: Please install apex from source (https://github.com/NVIDIA/apex) to use the fused layernorm kernel
# ...

# %%
# !python eval.py -c ./ckpt-fp16 -e 400
# Out:
# Accuracy of the model on the test images: 49.82 %, correct: 4982, total: 10000

# %%
# !python eval_all_checkpoints.py -c ./ckpt-fp16
# Out:
# Epoch 25, Accuracy: 34.19 %, correct: 3419, total: 10000
# Epoch 160, Accuracy: 42.24 %, correct: 4224, total: 10000
# Epoch 195, Accuracy: 46.86 %, correct: 4686, total: 10000
# Epoch 155, Accuracy: 43.71 %, correct: 4371, total: 10000
# Epoch 85, Accuracy: 41.19 %, correct: 4119, total: 10000
# Epoch 380, Accuracy: 49.84 %, correct: 4984, total: 10000
# Epoch 390, Accuracy: 49.85 %, correct: 4985, total: 10000
# Epoch 335, Accuracy: 48.98 %, correct: 4898, total: 10000
# Epoch 190, Accuracy: 47.87 %, correct: 4787, total: 10000
# Epoch 360, Accuracy: 49.49 %, correct: 4949, total: 10000
# Epoch 240, Accuracy: 48.62 %, correct: 4862, total: 10000
# Epoch 355, Accuracy: 49.68 %, correct: 4968, total: 10000
# Epoch 10, Accuracy: 14.73 %, correct: 1473, total: 10000
# Epoch 125, Accuracy: 39.38 %, correct: 3938, total: 10000
# Epoch 350, Accuracy: 49.58 %, correct: 4958, total: 10000
# Epoch 70, Accuracy: 37.95 %, correct: 3795, total: 10000
# ...

# %%
# !colossalai run --nproc_per_node 4 train.py -c ./ckpt-fp32 -p torch_ddp_fp32 > run.log
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# /home/wdebang/hdd/miniconda3/envs/py10/lib/python3.10/site-packages/colossalai/shardformer/layer/normalization.py:45: UserWarning: Please install apex from source (https://github.com/NVIDIA/apex) to use the fused layernorm kernel
#   warnings.warn("Please install apex from source (https://github.com/NVIDIA/apex) to use the fused layernorm kernel")
# /home/wdebang/hdd/miniconda3/envs/py10/lib/python3.10/site-packages/colossalai/shardformer/layer/normalization.py:45: UserWarning: Please install apex from source (https://github.com/NVIDIA/apex) to use the fused layernorm kernel
# ...
